# %%
# Week 1: Excel Auto-Updater - Data Exploration
import pandas as pd
from pathlib import path

# Path ke file Excel dummy
data_path = Path("../data/raw/sample_data.xlsx")

#Load Excel
df = pd.read_excel(data_path)

# Lihat 5 baris pertama
print(df.head())

#Informasi dasar
print(df.info())

# Statistik deskriptif
print(df.describe())

# Contoh filtering / manipulasi
Sales_over_120 = df[df['Sales] > 120]
print("Sales > 120:\n", Sales_over_120)

# Insight
# - Pastikan kolom sesuai dengan nama yang akan digunakan di script update_excel.py
# - Periksa tipe data untuk kolom Date (harus datetime)
